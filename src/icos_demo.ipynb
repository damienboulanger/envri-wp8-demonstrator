# %%
import query_icos

# %%
query_icos.get_list_platforms()
# Out:
# [{'uri': 'http://meta.icos-cp.eu/resources/stations/AS_BIR',
#   'short_name': 'BIR',
#   'long_name': 'Birkenes',
#   'country': 'NO',
#   'latitude': '58.3886',
#   'longitude': '8.2519',
#   'ground_elevation': '219.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_GAT',
#   'short_name': 'GAT',
#   'long_name': 'Gartow',
#   'country': 'DE',
#   'latitude': '53.0657',
#   'longitude': '11.4429',
#   'ground_elevation': '70.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_HEL',
#   'short_name': 'HEL',
#   'long_name': 'Helgoland',
#   'country': 'DE',
#   'latitude': '54.1804',
#   'longitude': '7.8833',
#   'ground_elevation': '43.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_HPB',
#   'short_name': 'HPB',
#   'long_name': 'Hohenpeissenberg',
#   'country': 'DE',
#   'latitude': '47.8011',
#   'longitude': '11.0246',
#   'ground_elevation': '934.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_HTM',
#   'short_name': 'HTM',
#   'long_name': 'Hyltemossa',
#   'country': 'SE',
#   'latitude': '56.0976',
#   'longitude': '13.4189',
#   'ground_elevation': '115.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_SMR',
#   'short_name': 'SMR',
#   'long_name': 'Hyytiälä',
#   'country': 'FI',
#   'latitude': '61.8474',
#   'longitude': '24.2947',
#   'ground_elevation': '181.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_IPR',
#   'short_name': 'IPR',
#   'long_name': 'Ispra',
#   'country': 'IT',
#   'latitude': '45.8147',
#   'longitude': '8.636',
#   'ground_elevation': '210.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_JFJ',
#   'short_name': 'JFJ',
#   'long_name': 'Jungfraujoch',
#   'country': 'CH',
#   'latitude': '46.5475',
#   'longitude': '7.9851',
#   'ground_elevation': '3580.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_KIT',
#   'short_name': 'KIT',
#   'long_name': 'Karlsruhe',
#   'country': 'DE',
#   'latitude': '49.0915',
#   'longitude': '8.4249',
#   'ground_elevation': '110.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_KRE',
#   'short_name': 'KRE',
#   'long_name': 'Křešín u Pacova',
#   'country': 'CZ',
#   'latitude': '49.572',
#   'longitude': '15.08',
#   'ground_elevation': '534.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_RUN',
#   'short_name': 'RUN',
#   'long_name': 'La Réunion',
#   'country': 'FR',
#   'latitude': '-21.0796',
#   'longitude': '55.3841',
#   'ground_elevation': '2154.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_LMP',
#   'short_name': 'LMP',
#   'long_name': 'Lampedusa',
#   'country': 'IT',
#   'latitude': '35.5181',
#   'longitude': '12.6322',
#   'ground_elevation': '45.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_LIN',
#   'short_name': 'LIN',
#   'long_name': 'Lindenberg',
#   'country': 'DE',
#   'latitude': '52.1663',
#   'longitude': '14.1226',
#   'ground_elevation': '73.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_LUT',
#   'short_name': 'LUT',
#   'long_name': 'Lutjewad',
#   'country': 'NL',
#   'latitude': '53.4036',
#   'longitude': '6.3528',
#   'ground_elevation': '1.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_CMN',
#   'short_name': 'CMN',
#   'long_name': 'Monte Cimone',
#   'country': 'IT',
#   'latitude': '44.1936',
#   'longitude': '10.6999',
#   'ground_elevation': '2165.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_NOR',
#   'short_name': 'NOR',
#   'long_name': 'Norunda',
#   'country': 'SE',
#   'latitude': '60.0864',
#   'longitude': '17.4794',
#   'ground_elevation': '46.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_OPE',
#   'short_name': 'OPE',
#   'long_name': "Observatoire pérenne de l'environnement",
#   'country': 'FR',
#   'latitude': '48.5619',
#   'longitude': '5.5036',
#   'ground_elevation': '390.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_OXK',
#   'short_name': 'OXK',
#   'long_name': 'Ochsenkopf',
#   'country': 'DE',
#   'latitude': '50.03',
#   'longitude': '11.8083',
#   'ground_elevation': '1022.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_PAL',
#   'short_name': 'PAL',
#   'long_name': 'Pallas',
#   'country': 'FI',
#   'latitude': '67.9733',
#   'longitude': '24.1157',
#   'ground_elevation': '565.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_PRS',
#   'short_name': 'PRS',
#   'long_name': 'Plateau Rosa',
#   'country': 'IT',
#   'latitude': '45.93',
#   'longitude': '7.7',
#   'ground_elevation': '3480.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_PUI',
#   'short_name': 'PUI',
#   'long_name': 'Puijo',
#   'country': 'FI',
#   'latitude': '62.9096',
#   'longitude': '27.6549',
#   'ground_elevation': '232.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_PUY',
#   'short_name': 'PUY',
#   'long_name': 'Puy de Dôme',
#   'country': 'FR',
#   'latitude': '45.7719',
#   'longitude': '2.9658',
#   'ground_elevation': '1465.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_SAC',
#   'short_name': 'SAC',
#   'long_name': 'Saclay',
#   'country': 'FR',
#   'latitude': '48.7227',
#   'longitude': '2.142',
#   'ground_elevation': '160.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_STE',
#   'short_name': 'STE',
#   'long_name': 'Steinkimmen',
#   'country': 'DE',
#   'latitude': '53.0431',
#   'longitude': '8.4588',
#   'ground_elevation': '29.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_SVB',
#   'short_name': 'SVB',
#   'long_name': 'Svartberget',
#   'country': 'SE',
#   'latitude': '64.256',
#   'longitude': '19.775',
#   'ground_elevation': '269.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_TOH',
#   'short_name': 'TOH',
#   'long_name': 'Torfhaus',
#   'country': 'DE',
#   'latitude': '51.8088',
#   'longitude': '10.535',
#   'ground_elevation': '801.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_TRN',
#   'short_name': 'TRN',
#   'long_name': 'Trainou',
#   'country': 'FR',
#   'latitude': '47.9647',
#   'longitude': '2.1125',
#   'ground_elevation': '131.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_UTO',
#   'short_name': 'UTO',
#   'long_name': 'Utö - Baltic sea',
#   'country': 'FI',
#   'latitude': '59.7839',
#   'longitude': '21.3672',
#   'ground_elevation': '8.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_ZEP',
#   'short_name': 'ZEP',
#   'long_name': 'Zeppelin',
#   'country': 'NO',
#   'latitude': '78.9072',
#   'longitude': '11.8867',
#   'ground_elevation': '474.0',
#   'RI': 'ICOS',
#   'theme': 'AS'},
#  {'uri': 'http://meta.icos-cp.eu/resources/stations/AS_ZSF',
#   'short_name': 'ZSF',
#   'long_name': 'Zugspitze',
#   'country': 'DE',
#   'latitude': '47.4165',
#   'longitude': '10.9796',
#   'ground_elevation': '2666.0',
#   'RI': 'ICOS',
#   'theme': 'AS'}]

# %%
query_icos.get_list_variables()
# Out:
# [{'variable_name': 'AP', 'ECV_name': ['Pressure (surface)', 'Pressure', 'ap']},
#  {'variable_name': 'WD',
#   'ECV_name': ['Surface Wind Speed and direction', 'wd']},
#  {'variable_name': 'WS',
#   'ECV_name': ['Surface Wind Speed and direction', 'ws']},
#  {'variable_name': 'AT',
#   'ECV_name': ['Temperature (near surface)', 'Temperature', 'at']},
#  {'variable_name': 'RH',
#   'ECV_name': ['Water Vapour (surface)',
#    'Water Vapour (Relative Humidity)',
#    'rh']},
#  {'variable_name': 'co2',
#   'ECV_name': ['Carbon Dioxide',
#    'Carbon Dioxide, Methane and other Greenhouse gases',
#    'Tropospheric CO2',
#    'co2']},
#  {'variable_name': 'co',
#   'ECV_name': ['Carbon Monoxide',
#    'Carbon Dioxide, Methane and other Greenhouse gases',
#    'co']},
#  {'variable_name': 'ch4',
#   'ECV_name': ['Methane',
#    'Carbon Dioxide, Methane and other Greenhouse gases',
#    'Tropospheric CH4',
#    'ch4']},
#  {'variable_name': 'n2o',
#   'ECV_name': ['Nitrous Oxide',
#    'Carbon Dioxide, Methane and other Greenhouse gases',
#    'n2o']}]

# %%
ds = query_icos.query_datasets(variables=['temperature'],temporal=['2021-01-01','2021-12-31'])

# %%
for d in ds:
    print(d)
# Out:
# {'title': 'ICOS_ATC_L2_L2-2021.1_GAT_2.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/0HxLXMXolAVqfcuqpysYz8jK', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-05-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'GAT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HPB_93.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/4wFOu-wmFE066BWfb104OPR0', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2015-09-18T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HPB'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HPB_131.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/7rgmWszKVW6pJavZ7p4vkwd_', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2015-09-18T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HPB'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_GAT_60.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/JF5TyuXlzYZV8EOo06He5c52', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-05-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'GAT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_GAT_30.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/XsNP7OyAW-OkUBwELbisTd1Z', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-05-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'GAT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HEL_60.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/Z_4XN1B-stQuV4ewG5LtzpZq', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2020-11-17T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HEL'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HPB_50.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/_ORIq7v9QJakcTr4BY8dMM7L', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2015-09-18T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HPB'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HEL_110.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/hCokcmgbUvV6OOpnm6ZPp5Vv', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2020-11-17T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HEL'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_GAT_341.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/k0SrQssJZ9gXz2_dULgVECzg', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-05-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'GAT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_GAT_132.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/l6F8nLrZAidjcpXvmjU3ljWa', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-05-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'GAT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_CMN_8.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/mt6zwCCybUUumnEGWV-9nwoB', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-05-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'CMN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HEL_2.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/pbfr-D_fSwHuFNhViMkZW7-9', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2020-11-17T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HEL'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HTM_3.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/tAizYkloR3IZqIh1Fr9F_Er_', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-04-22T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HTM'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_GAT_216.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/wayZ_7GtFuTmEB0cx5-ttSmp', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-05-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'GAT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HTM_150.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/pIYUbAi1RgRY7WZZOINCKx2V', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-09-26T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HTM'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HTM_30.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/B5xkwlcOHS5TTn8Dre1qYugW', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-09-26T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HTM'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_HTM_70.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/XiHyVZPCcvfF5DJhZmoLomR3', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-09-26T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'HTM'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_IPR_100.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/HebaXoKxVrZReGPsfLYziaXu', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-12-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'IPR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_IPR_40.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/AAUlIgmCG10R1SuBjzWbnuV4', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-12-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'IPR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_IPR_60.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/ksIYCjLaExDYXq7u74RRGwAD', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-12-10T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'IPR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_JFJ_1.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/xsckbl2yDjpeHLPyl6zjnHLS', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-12-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'JFJ'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_JFJ_10.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/DvBWpF9KW-aC76pXGs0nv-xl', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-12-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'JFJ'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_JFJ_2.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/QmyM5lLJciNb3vHOeXazAZ-d', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-12-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'JFJ'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KIT_100.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/mp_uKGD_zBmhRHzMFmDSyR0P', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-08-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KIT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KIT_2.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/sMNhXZqezCYTs6q3mRLkkNin', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-08-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KIT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KIT_200.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/XmAQp7wf_OaECXI0P7WEbv5j', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-08-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KIT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KIT_30.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/vUKJd-7Jw66sV7mI6dNCaZK0', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-08-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KIT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KIT_60.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/N-9NJv5uB1lNvIOagHZ7Zy42', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-08-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KIT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KRE_10.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/B8R9u_sjmTHBoYbiTMd0jQ2h', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-04-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KRE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KRE_125.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/osHFSqx0rLJjc9Mh2zwwhKHs', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-04-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KRE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KRE_250.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/iDrQrAHHexzxIeVMqYCRZWnk', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-04-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KRE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_KRE_50.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/onGr9mYhzptx-eyIY2n-2Jyc', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-04-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'KRE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_LIN_10.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/P_ZSmvSMyYod5Tw40_D-6Bob', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-02-21T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'LIN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_LIN_2.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/CDpawayQJRaIvb8FeNX58Ywu', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-02-21T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'LIN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_LIN_40.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/vo_Vp67OQNjtuCi8ZhkMpmZA', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-02-21T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'LIN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_LIN_98.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/kKIyX94bJI-A-w_xvLW8w51R', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-02-21T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'LIN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_LMP_10.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/tSWpqs16RrUxhrRUOlBlmK3a', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2020-01-30T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'LMP'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_LMP_2.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/0_GMA1TQGEcZMynJfQlKHq0_', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2020-01-30T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'LMP'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_LUT_7.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/ZGFSINP3qLUdK7ZpQp22KQ8X', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-10-10T12:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'LUT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_LUT_60.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/ES3GxpOkD52vxUZ21SvT5toE', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-01-10T00:00:00Z', '2021-01-07T04:00:00Z'], 'platform_id': 'LUT'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_NOR_1.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/pxoLd79kKQr3_n5PEoFCP9ob', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-06-17T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'NOR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_NOR_100.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/ZY1F4cDU_sEvDFLNZnNdOsWM', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-06-17T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'NOR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_NOR_32.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/lWn-MALacvhXImY1u3Hp86rI', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-06-17T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'NOR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_NOR_58.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/n8qHt0JyAFeShQI82Vaqd1pr', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-06-17T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'NOR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_OPE_10.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/krHiDuNJ_xa83jHOGGzSeFkQ', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-08-18T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'OPE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_OPE_120.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/PAhVVd4uGUnxTUqHB1p8bCG6', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-08-18T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'OPE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_OPE_50.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/ChDpSeP-tdcHc9XqmZW0pHhN', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-05-17T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'OPE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_OPE_1.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/Ps352-exnPK31NIQOBxJBGnX', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-07-05T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'OPE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_OXK_2.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/eqWWuVAGqfKTbOoN1WHJLkA0', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-09-25T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'OXK'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_OXK_23.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/DywwdjEZ65RVmQIe2QB4wGNJ', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-09-25T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'OXK'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_OXK_90.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/6VorkH2lWx4E74T7llLnkk_q', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-09-25T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'OXK'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_OXK_163.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/2brmdQ2l-MtiN91kfxNqgGb-', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-09-25T10:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'OXK'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_PAL_2.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/omWtdcJr7XwvDySAxdMd_Zsm', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-09-16T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'PAL'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_PAL_7.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/vX345nyN0FnrzlVKW6MPe7Vi', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-09-16T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'PAL'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_PAL_9.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/_sJl6T-5BrCyPbFIJTthHIJY', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-09-16T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'PAL'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_PUY_10.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/9rPR1NA0T-hKFiFrKEKcKbl-', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-06-20T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'PUY'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_RUN_6.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/0fYDo93HHTR3HDrK4MDRQ6Q6', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-09-13T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'RUN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SAC_1.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/NS0MX3JQ3oP_jD0oPfxZHGsx', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-05-31T00:00:00Z', '2021-01-31T19:00:00Z'], 'platform_id': 'SAC'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SAC_100.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/Ho9ysr2XIGE5prQGawSDk3Xm', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-05-31T00:00:00Z', '2021-01-31T07:00:00Z'], 'platform_id': 'SAC'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SAC_60.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/R2gER71ADUG7GlLZI04lKbzZ', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-05-31T00:00:00Z', '2021-01-31T19:00:00Z'], 'platform_id': 'SAC'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SMR_125.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/Mt9bIAUihr6dhIJ6pVTOSFK3', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-12-13T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'SMR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SMR_16.8_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/jdEYaqlTP6_Z7CxNelt7N3ah', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-12-13T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'SMR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SMR_67.2_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/jxEo8CfEq8XTP6eUmzvlAYNE', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-12-13T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'SMR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SMR_33.6_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/TB9do7KJ2QdRm8hrkzIc5cKm', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-09-27T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'SMR'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_STE_127.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/Ij_kygtF0_Ojn0zAMkMmdVZ1', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-07-22T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'STE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_STE_187.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/qrLBjLZxtGlPbAHUByKIhe6E', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-07-22T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'STE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_STE_2.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/RBNgmNpgKa_DtEJxgaQiH8B5', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-07-22T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'STE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_STE_32.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/TuFPaXPm3jFiPst5GG381zz6', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-07-22T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'STE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_STE_82.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/c20F8syQojobX5JRjUtU9Ot4', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-07-22T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'STE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_STE_252.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/_TmtresOSlklZSSaSl1OmOKO', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2019-08-27T11:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'STE'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SVB_2.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/e-mog-z-a1dFKa5dX50JiCtj', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-10-21T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'SVB'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SVB_35.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/27vJGF8ExfpXvWb0OqPe7gju', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-10-26T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'SVB'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SVB_85.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/jtskT1A5hS2wQb5DjQQTL9Sp', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-10-26T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'SVB'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_SVB_150.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/iDLauhdR8fb4z63NF656rwWK', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-10-27T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'SVB'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TOH_10.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/Yo0QuDj5oSMHMsxCcurg9j7S', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-01-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TOH'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TOH_147.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/jDFdJxfoJYRXdIpbKTLb_mSq', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-01-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TOH'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TOH_2.5_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/Y4WZLKw4oixybJ0gMptj-uwP', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-01-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TOH'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TOH_76.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/btzIOSnlu2G3Jq8u-RTA1Frg', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-01-01T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TOH'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TOH_110.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/Bg0BioQRxNCv917zB41gvvR8', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-06-21T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TOH'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TRN_5.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/BjO_OkJw1uV9HnOetz5NNFYf', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-03-16T12:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TRN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TRN_50.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/VeKv5bVAxbwQ86GIrTFhAovz', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2016-11-03T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TRN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TRN_100.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/MNzAUwbjouuH8Iivtq8s8Xmo', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-03-06T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TRN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_TRN_180.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/eITqufrMZ3W5dlPc3nJ0pj0g', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-03-06T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'TRN'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_UTO_53.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/mgc6EmBUjd7EK71M97IoLLQi', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-03-09T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'UTO'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_UTO_-3.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/-RuN1VyqMApODlYUnaDl7FZ9', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-12-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'UTO'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_UTO_58.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/uf62dFb-nVRHiN5r9ZNuVPnA', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2018-12-12T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'UTO'}
# {'title': 'ICOS_ATC_L2_L2-2021.1_ZEP_15.0_CTS_MTO.zip', 'urls': [{'url': 'https://meta.icos-cp.eu/objects/xdrxpuGvhKKgat5Zbu_w2P10', 'type': 'landing_page'}], 'ecv_variables': ['Pressure (surface)', 'Surface Wind Speed and direction', 'Temperature (near surface)', 'Water Vapour (surface)'], 'time_period': ['2017-07-27T00:00:00Z', '2021-01-31T23:00:00Z'], 'platform_id': 'ZEP'}

# %%
d('title')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6acf907aa234> in <module>
# ----> 1 d('title')
#
# TypeError: 'dict' object is not callable

# %%
query_icos.query_datasets(variables=['n2o'],temporal=['2018-01-01','2018-12-31'])

# %%
data = query_icos.read_dataset('https://meta.icos-cp.eu/objects/MEQ1hOwDjVYBQky5u3-BVFxf')
data
